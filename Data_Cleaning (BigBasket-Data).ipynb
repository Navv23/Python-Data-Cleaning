# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Importing the dataset

# %%
df = pd.read_csv(r"C:/Users/navne/Desktop/Projects - Data analysis/Big Basket/BigBasket Products.csv")

# %% [markdown]
# # 2. Checking the Structure, Datatype and Columns

# %%
df.columns
# Out:
# Index(['index', 'product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
df.shape
# Out:
# (27555, 10)

# %%
df.dtypes
# Out:
# index             int64
# product          object
# category         object
# sub_category     object
# brand            object
# sale_price      float64
# market_price    float64
# type             object
# rating          float64
# description      object
# dtype: object

# %%
df.drop('description',axis = 1, inplace = True) #dropped column

# %%
df.columns
# Out:
# Index(['index', 'product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating'],
#       dtype='object')

# %%
df.rename(columns = {'index':'Index','product':'Product','category':'Category'
                     ,'sub_category':'SubCategory','brand':'Brand',
                     'sale_price':'Saleprice','market_price':'Marketprice','type':'Type',
                     'rating':'Rating'},inplace = True)
                      #making the columns more readable

# %%
df.head()
# Out:
#    Index                                            Product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  Category            SubCategory              Brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    Saleprice  Marketprice                      Type  Rating
# 0      220.0        220.0          Hair Oil & Serum     4.1
# 1      180.0        180.0    Water & Fridge Bottles     2.3
# ...

# %% [markdown]
# # 3. Dropping Duplicates | Handling Null Values

# %%
df['Product'].drop_duplicates(inplace = True) #There were no Duplicate Products

# %%
df1 = df.isnull().sum()

# %%
df1
# Out:
# Index             0
# Product           1
# Category          0
# SubCategory       0
# Brand             1
# Saleprice         0
# Marketprice       0
# Type              0
# Rating         8626
# dtype: int64

# %%
df1 = df['Rating'].value_counts()

# %%
df1
# Out:
# 4.2    2251
# 4.3    2140
# 4.0    2090
# 4.1    1769
# 5.0    1407
# 4.4    1038
# 3.9     932
# 3.8     866
# 4.5     798
# 3.0     684
# 3.7     672
# 3.5     536
# 3.6     447
# 3.3     400
# 1.0     387
# 4.6     322
# 3.4     303
# 4.7     287
# 2.0     237
# 4.8     199
# 3.2     181
# 3.1     163
# 2.5     132
# 2.8     125
# 2.7     116
# 2.3      94
# 2.9      79
# 2.6      58
# 4.9      53
# 1.5      32
# 2.4      29
# 2.2      24
# 1.8      22
# 1.7      22
# 2.1      10
# 1.3       9
# 1.4       6
# 1.9       4
# 1.6       3
# 1.2       2
# Name: Rating, dtype: int64

# %%
df['Rating'].fillna(method = 'bfill',inplace = True)

# %%
df3 = pd.DataFrame(df)

# %%
df3.head(5)
# Out:
#    Index                                            Product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  Category            SubCategory              Brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    Saleprice  Marketprice                      Type  Rating
# 0      220.0        220.0          Hair Oil & Serum     4.1
# 1      180.0        180.0    Water & Fridge Bottles     2.3
# ...

# %%
df3.isnull().sum()
# Out:
# Index          0
# Product        1
# Category       0
# SubCategory    0
# Brand          1
# Saleprice      0
# Marketprice    0
# Type           0
# Rating         0
# dtype: int64

# %%
df3.dropna(how = 'any',inplace = True)

# %%
df3.isnull().sum() #Removed Duplicates & Cleaned the null Values
# Out:
# Index          0
# Product        0
# Category       0
# SubCategory    0
# Brand          0
# Saleprice      0
# Marketprice    0
# Type           0
# Rating         0
# dtype: int64

# %% [markdown]
# # 4. Removing Outliers | Filtering | Sorting

# %%
df3.head(10)
# Out:
#    Index                                            Product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
# 5      6                  Germ - Removal Multipurpose Wipes
# 6      7                                       Multani Mati
# 7      8                  Hand Sanitizer - 70% Alcohol Base
# 8      9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9     10               Scrub Pad - Anti- Bacterial, Regular
#
#                  Category             SubCategory              Brand  \
# 0        Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets   Storage & Accessories         Mastercook
# 2    Cleaning & Household             Pooja Needs                Trm
# ...

# %%
df4 = df3.describe()

# %%
df4
# Out:
#               Index     Saleprice   Marketprice        Rating
# count  27553.000000  27553.000000  27553.000000  27553.000000
# mean   13778.124342    322.529145    382.073872      3.939168
# std     7954.838872    486.277432    581.747762      0.742874
# min        1.000000      2.450000      3.000000      1.000000
# 25%     6889.000000     95.000000    100.000000      3.700000
# 50%    13778.000000    190.000000    220.000000      4.100000
# 75%    20667.000000    359.000000    425.000000      4.300000
# max    27555.000000  12500.000000  12500.000000      5.000000

# %%
df['PriceDifference'] = df['Marketprice']-df['Saleprice']

# %%
df3 = df

# %%
df3
# Out:
#        Index                                            Product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      Category               SubCategory  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df3.dropna(how = 'any').shape
# Out:
# (27553, 10)

# %%
df3[df3['Rating']>4]
# Out:
#        Index                                     Product  \
# 0          1      Garlic Oil - Vegetarian Capsule 500 mg
# 4          5          Creme Soft Soap - For Hands & Body
# 9         10        Scrub Pad - Anti- Bacterial, Regular
# 12        13             Face Wash - Oil Control, Active
# 14        15  Just Spray - Mosquito Repellent Room Spray
# ...      ...                                         ...
# 27543  27544         Popcorn - French Butter & Pink Salt
# 27546  27547               Organic Powder - Garam Masala
# 27548  27549                 Apple Cider Vinegar Shampoo
# 27553  27554                   Green Tea - Pure Original
# 27554  27555              United Dreams Go Far Deodorant
#
#                        Category               SubCategory  \
# 0              Beauty & Hygiene                 Hair Care
# 4              Beauty & Hygiene          Bath & Hand Wash
# 9          Cleaning & Household    Mops, Brushes & Scrubs
# ...

# %%
df3.to_csv('BigBasket_Cleaned.csv')
